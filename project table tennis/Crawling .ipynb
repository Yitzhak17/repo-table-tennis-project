# %% [markdown]
# # TTTM - Table Tennis Score Prediction - Israel
# ## in this project we will try to predict the score of the matches, and the forms that are filled by each team

# %% [markdown]
# ### Initial imports

# %%
import re
from datetime import datetime

import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Open csv

# %%
def read_csv(filename):
    return pd.read_csv("./" + filename)

# %% [markdown]
# ### Dataset - links to every player personal profile page
#
# #### crwaling to 'http://www.tttm.co.il', preparing the first dataset that will contain each player personal link

# %%
players_hrefs = []
top_players_df = None


def get_players_df():
    print("Start - Retrieve data from site")
    for i in range(1, 11):
        url = f"https://www.tttm.co.il/rk/MS-{i}/%D7%98%D7%A0%D7%99%D7%A1-%D7%A9%D7%95%D7%9C%D7%97%D7%9F-%D7%93%D7%99%D7%A8%D7%95%D7%92-%D7%92%D7%91%D7%A8%D7%99%D7%9D"
        res = requests.get(url)
        soup = BeautifulSoup(res.content, "html.parser")
        players = soup.find("table").find_all("tr")
        for player in players:
            a = player.find("a")
            try:
                players_hrefs.append(a["href"])
            except:
                continue

    players_to_df = {
        "name": [],
        "club": [],
        "rank": [],
        "category": [],
        "points": [],
        "id": [],
        "link": [],
    }

    for h in players_hrefs:
        res = requests.get("http://tttm.co.il" + h)
        soup = BeautifulSoup(res.content, "html.parser")
        name = soup.find("div", attrs={"class": "playerName"}).text
        player_presentation = soup.find("div", attrs={"class": "playerPresentation"})
        club = player_presentation.find("a").text
        rank = int(player_presentation.find("table").find("b").text)
        cat_points = player_presentation.find_all("span")
        category = cat_points[0].find("b").text
        points = float(cat_points[1].find("b").text)
        player_id = player_presentation.find("b").text.strip("\n").strip()
        print(name)
        players_to_df["name"].append(name)
        players_to_df["club"].append(club)
        players_to_df["rank"].append(rank)
        players_to_df["category"].append(category)
        players_to_df["points"].append(points)
        players_to_df["id"].append(player_id)
        players_to_df["link"].append(h)

    top_players_df = pd.DataFrame.from_dict(players_to_df)
    top_players_df["name"] = top_players_df["name"].str.strip("\n ")
    top_players_df["club"] = top_players_df["club"].str.strip("\n ")
    top_players_df.to_csv("players_data_table.csv", encoding="utf-8-sig")
    print("Done")

# %% [markdown]
# ## Trying to open the players_data_table.csv. if it doesnt work we will use the function above

# %%
try:
    top_players_df = read_csv("./players_data_table.csv")
    players_hrefs = top_players_df["link"]
except:
    get_players_df()
    top_players_df = read_csv("./players_data_table.csv")
    players_hrefs = top_players_df["link"]

# %%
try:
    top_players_df = top_players_df.drop("Unnamed: 0", axis=1)
except:
    pass

# %%
top_players_df
# Out:
#               name                      club  rank category  points    id  \
# 0    יונתן שוסטרמן             מ. בני הרצליה     1        S  1807.8   745
# 1      מיכאל טאובר            עירוני גבעתיים     2        S  1774.0   853
# 2        טל ישראלי                הפועל חיפה     3      E20  1756.9   651
# 3        עמית גורן    הפועל עירוני נוף הגליל     4        S  1712.4   676
# 4       גל אלגואטי             מ. בני הרצליה     5        S  1686.0  2183
# ..             ...                       ...   ...      ...     ...   ...
# 995  איציק סנדרוסי             הפועל ירושלים   996      S50   210.4  3618
# 996    מיכאל אזורב  מועדון ספורט מעלה אדומים   997      S60   210.0  3545
# 997      איתי רייך             מ. בני הרצליה   998      M13   208.9  7644
# 998   דניאל ירמיהו             הפועל ירושלים   999      S70   208.8  3464
# 999      שרון אהוד  מועדון ספורט מעלה אדומים  1000      S50   208.8  3436
#
#                       link
# 0     /p/745/יונתן-שוסטרמן
# 1       /p/853/מיכאל-טאובר
# 2         /p/651/טל-ישראלי
# 3         /p/676/עמית-גורן
# 4       /p/2183/גל-אלגואטי
# ..                     ...
# 995  /p/3618/איציק-סנדרוסי
# 996    /p/3545/מיכאל-אזורב
# 997      /p/7644/איתי-רייך
# 998   /p/3464/דניאל-ירמיהו
# 999      /p/3436/שרון-אהוד
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Let's impelement a function to return a single row of a player
# #### get_player_row(player_name) -> return player's row

# %%
def get_player_row(player_name):
    try:
        row = top_players_df[top_players_df["name"] == player_name]
        return row
    except:
        return None

# %%
test_row = get_player_row("רון דימנט")
test_row["name"].values[0]
# Out:
# 'רון דימנט'

# %% [markdown]
# ## After saving the first dataframe as csv we need to acquire more data
#
# ### Creating a new dataset for all the games that the players which we crawled to achieve their data earlier

# %%
games_to_df = {
    "match_id": [],
    "match_type": [],
    "date": [],
    "p1_id": [],
    "p1_name": [],
    "p1_club": [],
    "p1_rank": [],
    "p1_sets": [],
    "p1_home": [],
    "p1_points_gained": [],
    "p2_id": [],
    "p2_name": [],
    "p2_club": [],
    "p2_rank": [],
    "p2_sets": [],
    "p2_home": [],
    "p2_points_gained": [],
    "winner_id": [],
}

# %% [markdown]
# ## Creating the matches dataset
#
# ### We will now crawl on every player in top 500 and create a dataset of all the games that a player played

# %%
for h in range(500):
    try:
        res = requests.get("http://tttm.co.il" + players_hrefs[h])
        soup = BeautifulSoup(res.content, "html.parser")
        pages_arr = soup.find("div", attrs={"class": "rankpages"}).find_all("a")
        player_presentation = soup.find("div", attrs={"class": "playerPresentation"})
        player_details = {}
        player_details["name"] = (
            player_presentation.find("div", attrs={"class": "playerName"})
            .text.strip("\n")
            .strip()
        )
        player_details["id"] = player_presentation.find("b").text.strip("\n").strip()
        player_details["club"] = player_presentation.find("a").text.strip("\n").strip()
        print("Player number: ", h, " ", player_details)
        for p in range(9):
            res = requests.get("http://tttm.co.il" + pages_arr[p]["href"])
            soup = BeautifulSoup(res.content, "html.parser")
            table = soup.find("table", attrs={"class": "lstMatchs"})
            trays = table.findAll("tr")
            for tr in trays:
                try:
                    match_type = tr.find("a", attrs={"class": "fsClub"}).text.strip(
                        "\r\n                        "
                    )
                    td_list = tr.find_all("td")
                    match_id = td_list[0].text
                    date_string = td_list[2].text
                    p1_points_gained = 0
                    p2_points_gained = 0
                    try:
                        p1_points_gained = float(td_list[10].find("span").text)
                        delta = float(td_list[9].find("b").text)
                        if p1_points_gained < 0:
                            p2_points_gained = abs(p1_points_gained) * delta
                        else:
                            p2_points_gained = float(p1_points_gained / delta)
                            p2_points_gained = (-1) * (p2_points_gained)
                    except:
                        p1_points_gained = 0
                        p2_points_gained = 0
                    p1_id = player_details["id"]
                    p1_name = player_details["name"]
                    p1_club = player_details["club"]
                    p1_rank = td_list[1].find("span").text
                    p1_rank = float(re.findall("\d+\.\d+", p1_rank)[0])
                    p2_rank = td_list[6].text
                    p2 = td_list[5].find_all("a")
                    p2_name = p2[0].text.strip("    \r\n                    ")
                    p2_club = p2[1].text
                    p2_rank = float(td_list[6].text)
                    p2_id = top_players_df[top_players_df["name"] == p2_name][
                        "id"
                    ].values[0]
                    sets = td_list[8].text.split("-")
                    p2_sets = int(sets[0])
                    p1_sets = int(sets[1])
                    p2_home = np.nan
                    p1_home = np.nan
                    try:
                        teams = td_list[3].find("i").text.split("-")
                        if p2_club in teams[0]:
                            p2_home = 1
                            p1_home = 0

                        elif p2_club in teams[1]:
                            p1_home = 1
                            p2_home = 0

                        games_to_df["p2_home"].append(p2_home)
                        games_to_df["p1_home"].append(p1_home)

                    except:
                        games_to_df["p2_home"].append(p2_home)
                        games_to_df["p1_home"].append(p1_home)

                    date_time_obj = datetime.strptime(date_string, "%d/%m/%Y")

                    winner = p1_id if p1_sets > p2_sets else p2_id
                    games_to_df["p1_points_gained"].append(p1_points_gained)
                    games_to_df["p2_points_gained"].append(p2_points_gained)
                    games_to_df["match_id"].append(match_id)
                    games_to_df["match_type"].append(match_type)
                    games_to_df["date"].append(date_time_obj)
                    games_to_df["p1_id"].append(p1_id)
                    games_to_df["p1_club"].append(p1_club)
                    games_to_df["p1_name"].append(p1_name)
                    games_to_df["p1_rank"].append(p1_rank)
                    games_to_df["p2_id"].append(p2_id)
                    games_to_df["p2_club"].append(p2_club)
                    games_to_df["p2_name"].append(p2_name)
                    games_to_df["p2_rank"].append(p2_rank)

                    games_to_df["p1_sets"].append(p1_sets)
                    games_to_df["p2_sets"].append(p2_sets)
                    games_to_df["winner_id"].append(winner)

                except:
                    continue
    except:
        continue
# Out:
# Player number:  0   {'name': 'יונתן שוסטרמן', 'id': '745', 'club': 'מ. בני הרצליה'}
# Player number:  1   {'name': 'מיכאל טאובר', 'id': '853', 'club': 'עירוני גבעתיים'}
# Player number:  2   {'name': 'טל ישראלי', 'id': '651', 'club': 'הפועל חיפה'}
# Player number:  3   {'name': 'עמית גורן', 'id': '676', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  5   {'name': 'יניב שרון', 'id': '882', 'club': "בית''ר ראשון לציון"}
# Player number:  6   {'name': 'עמרי בן ארי', 'id': '894', 'club': 'עירוני גבעתיים'}
# Player number:  7   {'name': 'אביב בן ארי', 'id': '524', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  8   {'name': 'איתי אביבי', 'id': '2284', 'club': 'מ. בני הרצליה'}
# Player number:  9   {'name': 'גל פרפל', 'id': '741', 'club': 'הישגי כרמיאל'}
# Player number:  10   {'name': 'רון דוידוביץ', 'id': '881', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  11   {'name': 'עידן אוגורצב', 'id': '862', 'club': 'מכבי תל אביב'}
# Player number:  12   {'name': 'איתי שושן', 'id': '2625', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  13   {'name': 'מתן סימון', 'id': '341', 'club': 'עירוני גבעתיים'}
# Player number:  14   {'name': 'אור בשן', 'id': '865', 'club': 'מ. בני הרצליה'}
# Player number:  15   {'name': 'אורי אלמור', 'id': '2620', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  16   {'name': 'איסק אברמוב', 'id': '874', 'club': "בית''ר ראשון לציון"}
# Player number:  17   {'name': 'רון דימנט', 'id': '675', 'club': 'הישגי כרמיאל'}
# Player number:  18   {'name': 'דור אורן', 'id': '692', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  19   {'name': 'רונאל דוידוב', 'id': '806', 'club': 'מכבי דימונה'}
# Player number:  20   {'name': 'גיא קוחלי', 'id': '684', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  21   {'name': 'נתנאל אברמוב', 'id': '3181', 'club': "בית''ר ראשון לציון"}
# Player number:  22   {'name': 'אוהד פניאל', 'id': '891', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  24   {'name': 'יורי פורמן', 'id': '888', 'club': 'הפועל לוד'}
# Player number:  25   {'name': 'אדיר דניאל', 'id': '738', 'club': 'אופק קריית אונו'}
# Player number:  26   {'name': 'שמעון רבינוביץ', 'id': '869', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  27   {'name': 'בן יצחק', 'id': '617', 'club': 'מכבי תל אביב'}
# Player number:  28   {'name': 'אלכסיי נפלוקוב', 'id': '7692', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  29   {'name': 'אושר אשכנזי', 'id': '820', 'club': 'הפועל פתח תקווה'}
# Player number:  30   {'name': 'דניאל קושקרוב', 'id': '620', 'club': 'מכבי דימונה'}
# Player number:  31   {'name': 'זיו יצחק', 'id': '682', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  32   {'name': 'אביב עמידור', 'id': '130', 'club': 'הפועל ירושלים'}
# Player number:  33   {'name': 'פבל טמנוגורוד', 'id': '858', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  34   {'name': 'יניב קרמזין', 'id': '685', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  35   {'name': 'אור שטיין', 'id': '126', 'club': 'הפועל ירושלים'}
# Player number:  36   {'name': 'אלכסנדר קורס', 'id': '1453', 'club': "טנ''ש 2007 נתניה"}
# Player number:  37   {'name': 'בנצי בלנק', 'id': '878', 'club': 'הפועל לוד'}
# Player number:  38   {'name': 'שחר כרמון', 'id': '1992', 'club': 'מכבי תל אביב'}
# Player number:  39   {'name': 'אור מגן', 'id': '6771', 'club': 'הפועל פתח תקווה'}
# Player number:  40   {'name': 'עודד גרטמן', 'id': '930', 'club': 'מכבי תל אביב'}
# Player number:  41   {'name': 'איתמר אברמוב', 'id': '801', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  42   {'name': 'מתן עולי', 'id': '1945', 'club': 'מ. בני הרצליה'}
# Player number:  44   {'name': 'אושרי זפרן', 'id': '1172', 'club': 'הפועל גליל תחתון'}
# Player number:  45   {'name': 'עידן טרוסמן', 'id': '624', 'club': 'אליצור קריית אתא'}
# Player number:  46   {'name': 'נתן סגל', 'id': '626', 'club': 'הישגי כרמיאל'}
# Player number:  47   {'name': 'שחר גינסברג', 'id': '884', 'club': 'מכבי רחובות'}
# Player number:  48   {'name': 'צחי פרום', 'id': '965', 'club': 'מכבי תל אביב'}
# Player number:  49   {'name': 'אסף חננאל', 'id': '3082', 'club': 'אופק קריית אונו'}
# Player number:  50   {'name': 'עמנואל כהן', 'id': '2809', 'club': 'הפועל ירושלים'}
# Player number:  51   {'name': 'אמנון בן-שחר', 'id': '2596', 'club': 'מ. בני הרצליה'}
# Player number:  52   {'name': 'יוני ירמיהו', 'id': '845', 'club': 'הפועל לוד'}
# Player number:  53   {'name': 'גבריאל קלוו', 'id': '324', 'club': 'הפועל ירושלים'}
# Player number:  54   {'name': 'יונתן שיפמן', 'id': '901', 'club': 'מכבי תל אביב'}
# Player number:  55   {'name': 'אבנר לוין', 'id': '1199', 'club': 'מ. בני הרצליה'}
# Player number:  56   {'name': 'יבגני ספוזניקוב', 'id': '523', 'club': 'הפועל בת ים'}
# Player number:  57   {'name': 'בן סורוקין', 'id': '144', 'club': 'הפועל ירושלים'}
# Player number:  58   {'name': 'יניב שפס', 'id': '1867', 'club': 'הפועל ביחד עברון מזרעה'}
# Player number:  59   {'name': 'דוד אלטרץ', 'id': '107', 'club': 'הפועל ירושלים'}
# Player number:  60   {'name': 'אלעד אברויה', 'id': '935', 'club': 'הפועל אשדוד'}
# Player number:  61   {'name': 'דימיטרי פלאי', 'id': '6607', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  62   {'name': 'אליה זבולוני', 'id': '4523', 'club': 'אופק קריית אונו'}
# Player number:  63   {'name': 'שי רוטברת', 'id': '798', 'club': 'מכבי דימונה'}
# Player number:  64   {'name': 'עידן לוי', 'id': '2491', 'club': 'מכבי תל אביב'}
# Player number:  65   {'name': 'דמיטרי אברמנקו', 'id': '1591', 'club': 'עירוני מעלות תרשיחא'}
# Player number:  66   {'name': 'גאורגי טוניאן', 'id': '1205', 'club': 'מכבי גבירול באר שבע'}
# Player number:  67   {'name': 'עידו אטקין', 'id': '705', 'club': 'עירוני גבעתיים'}
# Player number:  68   {'name': 'יורי דימנט', 'id': '1597', 'club': 'עירוני מעלות תרשיחא'}
# Player number:  69   {'name': 'שמעון קלברס', 'id': '1475', 'club': 'הפועל לוד'}
# Player number:  70   {'name': 'שחר גילעד', 'id': '1439', 'club': 'הפועל מבואות חרמון'}
# Player number:  72   {'name': 'יניב יאכלביץ', 'id': '5546', 'club': 'עירוני גבעתיים'}
# Player number:  73   {'name': 'בן הורנשטיין', 'id': '2964', 'club': 'עירוני גבעתיים'}
# Player number:  74   {'name': 'נדב דהן', 'id': '1844', 'club': 'הפועל חיפה'}
# Player number:  75   {'name': 'יצחק אברמוביץ', 'id': '1112', 'club': 'הפועל לוד'}
# Player number:  76   {'name': 'אופק ביתן', 'id': '4191', 'club': 'הפועל פתח תקווה'}
# Player number:  77   {'name': 'בוריס קושניר', 'id': '972', 'club': "טנ''ש נס ציונה"}
# Player number:  79   {'name': 'יבגני ריזוב', 'id': '2889', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  80   {'name': "אדם נג'ר", 'id': '6604', 'club': 'מ. בני הרצליה'}
# Player number:  81   {'name': 'ניר רחליס', 'id': '2292', 'club': 'הפועל גליל תחתון'}
# Player number:  82   {'name': 'טל מיטרני', 'id': '1660', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  83   {'name': 'סמיון גנדלר', 'id': '908', 'club': 'מכבי גבירול באר שבע'}
# Player number:  84   {'name': 'מתן מן', 'id': '1392', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  85   {'name': 'עידו אמיגה', 'id': '6350', 'club': 'הפועל ירושלים'}
# Player number:  86   {'name': 'אביב הלפרן', 'id': '657', 'club': 'הישגי כרמיאל'}
# Player number:  87   {'name': 'חביב בן דוד', 'id': '1204', 'club': "בית''ר באר שבע"}
# Player number:  88   {'name': 'רועי ארליך', 'id': '890', 'club': 'מכבי תל אביב'}
# Player number:  89   {'name': 'שון ברקטוב', 'id': '621', 'club': "בית''ר באר שבע"}
# Player number:  90   {'name': 'גיל אביבי', 'id': '507', 'club': 'הפועל חיפה'}
# Player number:  92   {'name': 'עידו בן שימחון', 'id': '1611', 'club': "טנ''ש 2007 נתניה"}
# Player number:  93   {'name': 'טל פוקס', 'id': '1769', 'club': 'מכבי שהם'}
# Player number:  94   {'name': 'יעקב בוגן', 'id': '531', 'club': 'מכבי תל אביב'}
# Player number:  95   {'name': 'דור רזניק', 'id': '652', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  97   {'name': 'עידו רוזנבאום', 'id': '870', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  98   {'name': 'אדי ישראלי', 'id': '892', 'club': 'הפועל חיפה'}
# Player number:  99   {'name': 'דובי פורטנוי', 'id': '876', 'club': 'מכבי תל אביב'}
# Player number:  100   {'name': 'יבגני ברבוי', 'id': '1408', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  101   {'name': 'רם שר', 'id': '934', 'club': "בית''ר באר שבע"}
# Player number:  102   {'name': 'אמיר מרציאנו', 'id': '4266', 'club': 'מכבי תל אביב'}
# Player number:  103   {'name': 'רביד ברנדמן', 'id': '3833', 'club': 'אופק קריית אונו'}
# Player number:  104   {'name': 'עידן עופר', 'id': '6174', 'club': 'מכבי רחובות'}
# Player number:  105   {'name': 'ארז זכריה', 'id': '921', 'club': 'מ. בני הרצליה'}
# Player number:  106   {'name': 'דן סולודר', 'id': '752', 'club': 'הפועל לוד'}
# Player number:  107   {'name': 'איגור סלבין', 'id': '1907', 'club': 'הפועל אשקלון'}
# Player number:  108   {'name': 'עמית בן-עמי', 'id': '2830', 'club': 'אופק קריית אונו'}
# Player number:  110   {'name': 'שימי אסרף', 'id': '926', 'club': 'הפועל חיפה'}
# Player number:  111   {'name': 'יהונתן איתן', 'id': '2203', 'club': 'עירוני גבעתיים'}
# Player number:  113   {'name': 'ציגי דיקשטיין', 'id': '970', 'club': 'עירוני גבעתיים'}
# Player number:  114   {'name': 'רון אוישר', 'id': '635', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  115   {'name': 'מתן פוקס', 'id': '4304', 'club': "בית''ר ראשון לציון"}
# Player number:  116   {'name': 'יובל נוטנקו', 'id': '817', 'club': 'הפועל פתח תקווה'}
# Player number:  117   {'name': 'חנוך לנר', 'id': '1370', 'club': 'הפועל באר טוביה'}
# Player number:  118   {'name': 'רומן דריפסקה', 'id': '7714', 'club': 'מכבי דימונה'}
# Player number:  119   {'name': 'יניב בלנק', 'id': '929', 'club': "בית''ר רמלה"}
# Player number:  120   {'name': 'מקסים גולדין', 'id': '6601', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  121   {'name': 'דניאל זהר', 'id': '2028', 'club': 'אופק קריית אונו'}
# Player number:  122   {'name': 'פיליפ קושנר', 'id': '2387', 'club': "מכבי ראשל''צ טנ''ש"}
# Player number:  123   {'name': 'אביב גורדון', 'id': '1381', 'club': "טנ''ש נס ציונה"}
# Player number:  124   {'name': 'איגור גולדברג', 'id': '1359', 'club': 'הפועל בת ים'}
# Player number:  125   {'name': 'תומר הדר', 'id': '7044', 'club': 'מ. בני הרצליה'}
# Player number:  126   {'name': 'ליאור קוסטינסקי', 'id': '683', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  127   {'name': 'אריאל שפירא', 'id': '532', 'club': 'טניס שולחן חיפה'}
# Player number:  128   {'name': 'יעקב שי', 'id': '841', 'club': "בית''ר באר שבע"}
# Player number:  129   {'name': 'אלון לב', 'id': '949', 'club': 'הפועל דרום השרון'}
# Player number:  130   {'name': 'פבל סטסנקו', 'id': '2189', 'club': 'הפועל בת ים'}
# Player number:  131   {'name': 'עמית יצחק', 'id': '2957', 'club': 'מכבי תל אביב'}
# Player number:  132   {'name': 'דני ליבשיץ', 'id': '293', 'club': 'הפועל ירושלים'}
# Player number:  133   {'name': 'אלכסנדר סלצר', 'id': '1705', 'club': 'מכבי דימונה'}
# Player number:  134   {'name': 'יובל שריג', 'id': '5599', 'club': 'מכבי שהם'}
# Player number:  135   {'name': 'ניר יעקובי', 'id': '1373', 'club': 'ללא מועדון'}
# Player number:  136   {'name': 'תומר נעמה', 'id': '2952', 'club': 'עירוני גבעתיים'}
# Player number:  137   {'name': 'אבי נזרין', 'id': '959', 'club': 'הפועל אשדוד'}
# Player number:  138   {'name': 'אמיר רובינשטיין', 'id': '3675', 'club': 'הפועל לוד'}
# Player number:  140   {'name': 'גלעד לוין', 'id': '2720', 'club': "בית''ר ראשון לציון"}
# Player number:  141   {'name': 'דן זוילי', 'id': '2229', 'club': 'הפועל לוד'}
# Player number:  142   {'name': 'ארז סנדק', 'id': '2956', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  143   {'name': 'ארטיום קרביץ', 'id': '5529', 'club': 'הפועל בת ים'}
# Player number:  144   {'name': 'אדם בלנק', 'id': '895', 'club': "בית''ר רמלה"}
# Player number:  145   {'name': 'טומי גרינפלד', 'id': '4167', 'club': "בית''ר ראשון לציון"}
# Player number:  146   {'name': 'לירן בונציוק', 'id': '528', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  147   {'name': 'איתי חננאל', 'id': '687', 'club': 'אופק קריית אונו'}
# Player number:  148   {'name': 'אדר שקד', 'id': '857', 'club': 'הפועל לוד'}
# Player number:  149   {'name': 'גולן עוז', 'id': '1776', 'club': 'מכבי שהם'}
# Player number:  150   {'name': 'עידו פנסו', 'id': '673', 'club': 'אופק קריית אונו'}
# Player number:  151   {'name': 'יפתח אונא', 'id': '3143', 'club': "בית''ר באר שבע"}
# Player number:  152   {'name': 'אורי יצחקי', 'id': '145', 'club': 'מ. בני הרצליה'}
# Player number:  153   {'name': 'גיא בלוך', 'id': '902', 'club': 'מכבי שהם'}
# Player number:  154   {'name': 'מתן כהן', 'id': '830', 'club': 'מ. בני הרצליה'}
# Player number:  155   {'name': 'אפי גילקרוב', 'id': '2639', 'club': 'הפועל חולון'}
# Player number:  156   {'name': 'יבגני בלמן', 'id': '3646', 'club': 'הפועל בת ים'}
# Player number:  157   {'name': 'דוד גולן', 'id': '922', 'club': "מכבי ראשל''צ טנ''ש"}
# Player number:  158   {'name': 'סטניסלב בוייקנר', 'id': '1735', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  159   {'name': 'רן מנשה', 'id': '1937', 'club': "טנ''ש 2007 נתניה"}
# Player number:  160   {'name': 'ליאור סרף', 'id': '3205', 'club': 'הישגי כרמיאל'}
# Player number:  161   {'name': 'רוני רמסניק', 'id': '915', 'club': 'הפועל אשקלון'}
# Player number:  162   {'name': 'זאב סהר', 'id': '2644', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  163   {'name': 'שמעון פקטרמן', 'id': '1940', 'club': 'הפועל חיפה'}
# Player number:  164   {'name': 'יעקב אבידר', 'id': '905', 'club': "טנ''ש 2007 נתניה"}
# Player number:  165   {'name': 'רועי רוזנבלט', 'id': '903', 'club': 'הפועל אשדוד'}
# Player number:  166   {'name': "סרדר אפג'אן", 'id': '916', 'club': 'הפועל אילת'}
# Player number:  167   {'name': 'מקסים גנקין', 'id': '8447', 'club': 'הפועל ארנון רמת גן'}
# Player number:  168   {'name': 'אלכסנדר לוין', 'id': '1264', 'club': 'הפועל חיפה'}
# Player number:  171   {'name': 'יובל וולפרט', 'id': '2057', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  172   {'name': 'יוסף אזולאי', 'id': '2846', 'club': 'הפועל בת ים'}
# Player number:  173   {'name': 'עופר פוקס', 'id': '1772', 'club': 'מכבי שהם'}
# Player number:  175   {'name': 'יפים גורביץ', 'id': '989', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  176   {'name': 'איתי אוניק', 'id': '961', 'club': 'מ. בני הרצליה'}
# Player number:  177   {'name': 'נחום שמיס', 'id': '987', 'club': 'הפועל חיפה'}
# Player number:  178   {'name': 'יהלי מור', 'id': '5817', 'club': 'מכבי תל אביב'}
# Player number:  179   {'name': 'זאב גליקמן', 'id': '362', 'club': 'הפועל אשדוד'}
# Player number:  180   {'name': 'אלכסנדר סליטרניק', 'id': '1511', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  181   {'name': 'עדי אביאני', 'id': '2920', 'club': 'מ. בני הרצליה'}
# Player number:  182   {'name': 'אלכס קרנברג', 'id': '974', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  183   {'name': 'יואב אהרון', 'id': '5485', 'club': 'הפועל לוד'}
# Player number:  184   {'name': 'יובל בץ', 'id': '140', 'club': 'הפועל ירושלים'}
# Player number:  185   {'name': 'משה סימנה', 'id': '4741', 'club': 'הפועל גליל תחתון'}
# Player number:  186   {'name': 'אסף גונן', 'id': '1579', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  187   {'name': 'ניר אנגלר', 'id': '4707', 'club': 'הפועל לוד'}
# Player number:  188   {'name': 'איליה ריטבין', 'id': '2626', 'club': "בית''ר באר שבע"}
# Player number:  189   {'name': 'אורי מינץ', 'id': '2713', 'club': 'מכבי שהם'}
# Player number:  190   {'name': 'הילי ברבי', 'id': '2369', 'club': "בית''ר ראשון לציון"}
# Player number:  191   {'name': 'עדי סידלר', 'id': '1778', 'club': 'מכבי שהם'}
# Player number:  192   {'name': 'רועי חלמיש', 'id': '4650', 'club': "בית''ר ראשון לציון"}
# Player number:  193   {'name': 'סרגיי וינטראוב', 'id': '291', 'club': 'הפועל ירושלים'}
# Player number:  194   {'name': 'ניצן פרדריך', 'id': '2604', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  195   {'name': 'יהודה דרור', 'id': '1693', 'club': 'מ. בני הרצליה'}
# Player number:  197   {'name': 'גלעד אקסלרוד', 'id': '3088', 'club': 'אופק קריית אונו'}
# Player number:  198   {'name': 'פבל פרנקל', 'id': '946', 'club': 'מכבי דימונה'}
# Player number:  199   {'name': 'דניאל פטר', 'id': '833', 'club': 'מ. בני הרצליה'}
# Player number:  200   {'name': 'אלכסנדר שפירו', 'id': '2629', 'club': 'אליצור קריית אתא'}
# Player number:  201   {'name': 'כפיר גרטי', 'id': '1644', 'club': 'מכבי שהם'}
# Player number:  202   {'name': 'יוסי רוזנבלט', 'id': '998', 'club': 'הפועל אשדוד'}
# Player number:  203   {'name': 'אביב וייג', 'id': '6371', 'club': 'הפועל יוקנעם'}
# Player number:  204   {'name': 'בנימין שניידר', 'id': '2847', 'club': 'מכבי תל אביב'}
# Player number:  205   {'name': 'דמיטרי אסקוטסקי', 'id': '991', 'club': "מ.ק.מתנ''ס קריית גת"}
# Player number:  206   {'name': 'אלעד אסרף', 'id': '1512', 'club': 'הפועל חיפה'}
# Player number:  207   {'name': 'דוד גופר', 'id': '3036', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  208   {'name': 'רן מלינגר', 'id': '3055', 'club': 'הפועל גליל תחתון'}
# Player number:  209   {'name': 'מיכאל טברסקי', 'id': '844', 'club': 'הפועל לוד'}
# Player number:  212   {'name': 'רועי לימור', 'id': '1943', 'club': 'מ. בני הרצליה'}
# Player number:  213   {'name': 'ברק יולזרי', 'id': '1472', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  214   {'name': 'אופק פוני', 'id': '349', 'club': 'אופק קריית אונו'}
# Player number:  215   {'name': 'ניר חבצלת', 'id': '1978', 'club': "טנ''ש נס ציונה"}
# Player number:  217   {'name': 'דימיטרי קובל', 'id': '4672', 'club': 'הפועל אשדוד'}
# Player number:  218   {'name': 'בר אושר עובדיה', 'id': '4459', 'club': 'טניס שולחן חיפה'}
# Player number:  219   {'name': 'בצלאל מייר', 'id': '2296', 'club': 'הפועל חיפה'}
# Player number:  220   {'name': 'אילן דרמון', 'id': '322', 'club': 'מ. בני הרצליה'}
# Player number:  221   {'name': 'עידו טל', 'id': '3035', 'club': 'מכבי גדרה'}
# Player number:  222   {'name': 'שי דמארי', 'id': '1476', 'club': 'עירוני גבעתיים'}
# Player number:  223   {'name': 'ערן סגל', 'id': '1206', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  224   {'name': 'גנאדי גרינברג', 'id': '995', 'club': 'מ. בני הרצליה'}
# Player number:  225   {'name': 'אלכסנדר קורנמן', 'id': '1375', 'club': 'הפועל אשדוד'}
# Player number:  226   {'name': 'יוסי עטיה', 'id': '2572', 'club': 'הפועל לוד'}
# Player number:  227   {'name': 'דוד לוי', 'id': '1857', 'club': 'מכבי דימונה'}
# Player number:  228   {'name': 'ליחי גרינשטיין', 'id': '512', 'club': 'עירוני גבעתיים'}
# Player number:  229   {'name': 'יניב יוסף', 'id': '1333', 'club': "מ.ק.מתנ''ס קריית גת"}
# Player number:  230   {'name': 'יבגני מקלר', 'id': '1564', 'club': 'הפועל חיפה'}
# Player number:  231   {'name': 'עמית וולפרט', 'id': '1922', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  232   {'name': 'ולדימיר ברוסילובסקי', 'id': '898', 'club': 'הפועל אשדוד'}
# Player number:  233   {'name': 'אורי בן-זיו', 'id': '4126', 'club': 'אופק קריית אונו'}
# Player number:  234   {'name': 'יובל ורדי', 'id': '834', 'club': 'הפועל באר טוביה'}
# Player number:  235   {'name': 'יעקב שטרנברג', 'id': '975', 'club': "מכבי ראשל''צ טנ''ש"}
# Player number:  236   {'name': 'אלכס בינמן', 'id': '925', 'club': "בית''ר אשדוד"}
# Player number:  239   {'name': 'אלכסנדר זלנסקי', 'id': '2908', 'club': "טנ''ש נס ציונה"}
# Player number:  240   {'name': 'ערן גיט', 'id': '978', 'club': "טנ''ש נס ציונה"}
# Player number:  241   {'name': 'יהודה ברזילי', 'id': '4537', 'club': 'הפועל ירושלים'}
# Player number:  242   {'name': 'מקסים קוקוטוב', 'id': '849', 'club': 'אליצור קריית אתא'}
# Player number:  243   {'name': 'אנטולי לוינשטיין', 'id': '943', 'club': 'הפועל רמת ישי'}
# Player number:  244   {'name': 'רוני קליין', 'id': '5775', 'club': 'הפועל רמת ישי'}
# Player number:  245   {'name': 'מיכאל דיטיניס', 'id': '4271', 'club': 'הפועל חיפה'}
# Player number:  246   {'name': 'דוד מוסקוביץ', 'id': '3667', 'club': "בית''ר אשדוד"}
# Player number:  247   {'name': 'אלכסיי סקידנוב', 'id': '6930', 'club': 'הפועל אשדוד'}
# Player number:  248   {'name': 'ניר חן', 'id': '4576', 'club': 'הפועל יוקנעם'}
# Player number:  249   {'name': 'עידו דפני', 'id': '4494', 'club': 'הפועל לוד'}
# Player number:  250   {'name': 'דני בן שיטרית', 'id': '303', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  253   {'name': 'יפתח גסר', 'id': '1685', 'club': 'מכבי תל אביב'}
# Player number:  255   {'name': 'אלכסנדר אבשלומוב', 'id': '911', 'club': "טנ''ש נס ציונה"}
# Player number:  256   {'name': 'יובל רוטיץ', 'id': '1189', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  257   {'name': 'ערן ניר', 'id': '7025', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  258   {'name': 'יעקב ירוסלימסקי', 'id': '3112', 'club': "בית''ר ראשון לציון"}
# Player number:  259   {'name': 'דניאל דרזנר', 'id': '952', 'club': 'מכבי גדרה'}
# Player number:  260   {'name': 'מיכאל קרדונסקי', 'id': '1902', 'club': 'הפועל אילת'}
# Player number:  261   {'name': 'דן ריביניק', 'id': '1855', 'club': 'הפועל בת ים'}
# Player number:  263   {'name': 'עופר סיארה', 'id': '1711', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  264   {'name': 'דניאל שלום', 'id': '906', 'club': "טנ''ש נס ציונה"}
# Player number:  265   {'name': 'גבריאל גנדלמן', 'id': '4898', 'club': 'הפועל אשדוד'}
# Player number:  267   {'name': 'איילון בניימין', 'id': '3736', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  268   {'name': 'עמוס גינזבורג', 'id': '2242', 'club': "מכבי ראשל''צ טנ''ש"}
# Player number:  269   {'name': 'דיאגו שיקינסקי', 'id': '1526', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  270   {'name': 'אדיר דנינו', 'id': '4704', 'club': 'הפועל ירושלים'}
# Player number:  271   {'name': 'רוסלן ברקוטוב', 'id': '1328', 'club': "מ.ק.מתנ''ס קריית גת"}
# Player number:  272   {'name': 'אברהם שטרן', 'id': '1532', 'club': 'הפועל עירוני צפת'}
# Player number:  273   {'name': 'אריאל אזנקוט', 'id': '6929', 'club': 'מכבי שהם'}
# Player number:  274   {'name': 'אנטולי רפופורט', 'id': '7655', 'club': 'הפועל אילת'}
# Player number:  275   {'name': 'שי אוחיון', 'id': '5856', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  276   {'name': 'נדב פרצי', 'id': '4621', 'club': "בית''ר ראשון לציון"}
# Player number:  277   {'name': 'ולרי סרייב', 'id': '3804', 'club': "בית''ר רמלה"}
# Player number:  278   {'name': 'דן קריב', 'id': '2796', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  279   {'name': 'אילן אשכנזי', 'id': '7186', 'club': 'מ. בני הרצליה'}
# Player number:  280   {'name': 'רועי בכר', 'id': '6185', 'club': 'הפועל רמת ישי'}
# Player number:  281   {'name': 'אולג יוסימוב', 'id': '508', 'club': 'הפועל חיפה'}
# Player number:  282   {'name': 'ישי אדרי', 'id': '4250', 'club': 'טניס שולחן חיפה'}
# Player number:  283   {'name': 'מורן גביש', 'id': '3095', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  284   {'name': 'אפרים מרדכייב', 'id': '1327', 'club': "בית''ר באר שבע"}
# Player number:  285   {'name': 'ברק בינדר', 'id': '850', 'club': 'מ. בני הרצליה'}
# Player number:  286   {'name': 'ניב אברהם', 'id': '5595', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  287   {'name': 'דניס לב', 'id': '734', 'club': "בית''ר באר שבע"}
# Player number:  288   {'name': 'תומר הרכבי', 'id': '2198', 'club': 'הפועל דרום השרון'}
# Player number:  289   {'name': 'אלכס רייצס', 'id': '289', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  290   {'name': 'אסף אלמן', 'id': '6025', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  292   {'name': 'עירן ברנזון', 'id': '1540', 'club': 'הפועל עירוני צפת'}
# Player number:  293   {'name': 'מיכאל גינזבורג', 'id': '1701', 'club': 'מכבי גבירול באר שבע'}
# Player number:  296   {'name': 'יאיר שרעבי', 'id': '1006', 'club': "מכבי ראשל''צ טנ''ש"}
# Player number:  297   {'name': 'רון צפור', 'id': '2157', 'club': 'הפועל ירושלים'}
# Player number:  298   {'name': 'גולן סלמן', 'id': '2575', 'club': "קאנטרי ג' תל אביב"}
# Player number:  300   {'name': 'אורי כהן', 'id': '6614', 'club': 'אופק קריית אונו'}
# Player number:  301   {'name': 'ניר בראון', 'id': '1775', 'club': 'מכבי שהם'}
# Player number:  302   {'name': 'גיא צבי', 'id': '188', 'club': 'הפועל ירושלים'}
# Player number:  303   {'name': 'עודד נחשול', 'id': '1248', 'club': 'הפועל חיפה'}
# Player number:  305   {'name': 'דניס גונוחוב', 'id': '2245', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  306   {'name': 'יצחק ישראל', 'id': '1230', 'club': 'אליצור קריית אתא'}
# Player number:  307   {'name': 'מתן עופר', 'id': '913', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  308   {'name': 'אולג לנגרמן', 'id': '1989', 'club': 'אליצור קריית אתא'}
# Player number:  309   {'name': 'ולדימיר שנדרנקו', 'id': '985', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  310   {'name': 'שי רחמני', 'id': '1642', 'club': 'מכבי שהם'}
# Player number:  312   {'name': 'איגור נובק', 'id': '2606', 'club': 'טניס שולחן חיפה'}
# Player number:  313   {'name': "דניאל קרבצ'נקו", 'id': '4404', 'club': 'מ. בני הרצליה'}
# Player number:  315   {'name': 'סרגיי יגורוב', 'id': '2799', 'club': 'אליצור קריית אתא'}
# Player number:  316   {'name': 'דמיטרי רוגובין', 'id': '1398', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  317   {'name': 'אלברט לרמן', 'id': '4298', 'club': 'הישגי כרמיאל'}
# Player number:  318   {'name': 'רונן טולדנו', 'id': '1876', 'club': 'מכבי שהם'}
# Player number:  319   {'name': 'גילעד הוזליך', 'id': '526', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  320   {'name': 'אייל פיירשטיין', 'id': '764', 'club': 'הפועל ארנון רמת גן'}
# Player number:  321   {'name': 'אבישי אבוחצירא', 'id': '4526', 'club': 'הפועל ירושלים'}
# Player number:  322   {'name': 'יפים גלייזר', 'id': '1544', 'club': 'מכבי גבירול באר שבע'}
# Player number:  323   {'name': 'עומרי שקד', 'id': '7141', 'club': 'מכבי רחובות'}
# Player number:  324   {'name': 'דוד אלכסנדרוביץ', 'id': '2997', 'club': 'הפועל לוד'}
# Player number:  325   {'name': 'שמעון בוזגן', 'id': '996', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  327   {'name': 'גלעד רמתי', 'id': '1356', 'club': 'הפועל ארנון רמת גן'}
# Player number:  328   {'name': 'ויקטור מירוניוק', 'id': '3658', 'club': 'מכבי דימונה'}
# Player number:  330   {'name': 'שגיא מאירי', 'id': '1567', 'club': 'הפועל טירת הכרמל'}
# Player number:  331   {'name': 'אורי חאיה', 'id': '4190', 'club': "בית''ר רמלה"}
# Player number:  332   {'name': 'משה לוי', 'id': '2320', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  333   {'name': 'יאן לנדה', 'id': '1376', 'club': 'הפועל אשדוד'}
# Player number:  334   {'name': 'משה באבא', 'id': '986', 'club': 'הפועל ארנון רמת גן'}
# Player number:  335   {'name': 'שלומי אברהם', 'id': '2848', 'club': "מכבי ראשל''צ טנ''ש"}
# Player number:  336   {'name': 'דניאל בהונקר', 'id': '948', 'club': "בית''ר רמלה"}
# Player number:  337   {'name': 'שיזף שטרית', 'id': '3851', 'club': 'הפועל גליל תחתון'}
# Player number:  338   {'name': 'גיא קליג', 'id': '2672', 'club': 'הפועל ירושלים'}
# Player number:  339   {'name': 'רונן גבע', 'id': '4441', 'club': 'הפועל יוקנעם'}
# Player number:  340   {'name': "ויאצ'סלב גלפמן", 'id': '1798', 'club': "מכבי ראשל''צ טנ''ש"}
# Player number:  341   {'name': 'דורון חכם', 'id': '1787', 'club': 'מכבי תל אביב'}
# Player number:  342   {'name': 'ניבי דרבסי', 'id': '5587', 'club': 'הפועל האקדמיה לטניס שולחן מטה יהודה'}
# Player number:  343   {'name': 'אביעד צברי', 'id': '4638', 'club': 'אופק קריית אונו'}
# Player number:  344   {'name': 'יבגני רובמן', 'id': '517', 'club': 'כרמל מרכזי טניס שולחן חיפה'}
# Player number:  345   {'name': 'אייל תומר', 'id': '1796', 'club': "מכבי ראשל''צ טנ''ש"}
# Player number:  346   {'name': 'יקיר טאיבי', 'id': '6923', 'club': 'טניס שולחן חיפה'}
# Player number:  347   {'name': 'יעקב כהן גדול', 'id': '990', 'club': "בית''ר אשדוד"}
# Player number:  348   {'name': 'שליו אלפסי', 'id': '2281', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  349   {'name': 'ראובן אופציבסקי', 'id': '5473', 'club': "בית''ר באר שבע"}
# Player number:  350   {'name': 'אברהם פרטוש', 'id': '4680', 'club': 'הפועל רמת ישי'}
# Player number:  351   {'name': 'שרון שאדי', 'id': '2947', 'club': 'הפועל חולון'}
# Player number:  352   {'name': "ויאצ'סלב גנין", 'id': '4673', 'club': "בית''ר אשדוד"}
# Player number:  353   {'name': 'שמואל שור', 'id': '1374', 'club': 'הפועל אשדוד'}
# Player number:  354   {'name': 'עמית להב', 'id': '917', 'club': 'הפועל ארנון רמת גן'}
# Player number:  355   {'name': 'מיכאל שפירא', 'id': '2175', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  356   {'name': 'סיימון רוזין', 'id': '4366', 'club': 'הפועל פתח תקווה'}
# Player number:  357   {'name': 'בוריס שלפמן', 'id': '2995', 'club': 'הפועל לוד'}
# Player number:  359   {'name': 'אסף וקרט', 'id': '1440', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  360   {'name': 'שגיא גוטיינר', 'id': '2582', 'club': 'עירוני גבעתיים'}
# Player number:  362   {'name': 'משה אלנשיא', 'id': '984', 'club': "בית''ר אשדוד"}
# Player number:  363   {'name': 'אבי שמרי', 'id': '1449', 'club': 'הפועל חולון'}
# Player number:  364   {'name': 'יהלי זגורי', 'id': '5847', 'club': 'הישגי כרמיאל'}
# Player number:  365   {'name': 'מיכאל גורביץ', 'id': '999', 'club': 'אליצור קריית אתא'}
# Player number:  366   {'name': 'ויטלי זלמן', 'id': '1244', 'club': 'עמותת קריית מוצקין'}
# Player number:  367   {'name': 'עומר לוי', 'id': '693', 'club': 'הפועל גליל תחתון'}
# Player number:  368   {'name': 'ערן סימטוב', 'id': '2751', 'club': "בית''ר באר שבע"}
# Player number:  370   {'name': 'אולג אוישר', 'id': '1409', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  372   {'name': 'פבל זילברשטיין', 'id': '2641', 'club': 'הפועל יוקנעם'}
# Player number:  373   {'name': 'יגור קיסרי', 'id': '394', 'club': 'הפועל חיפה'}
# Player number:  374   {'name': 'ולרי ריאבצב', 'id': '7393', 'club': 'עירוני מעלות תרשיחא'}
# Player number:  375   {'name': 'רביד סלודובניק', 'id': '4244', 'club': 'עירוני גבעתיים'}
# Player number:  376   {'name': 'מיכאל מלכה', 'id': '1980', 'club': 'הפועל עירוני צפת'}
# Player number:  378   {'name': 'פבלו מעיין', 'id': '7656', 'club': 'הפועל ירושלים'}
# Player number:  381   {'name': 'מיכאל ליטבק', 'id': '2484', 'club': 'מכבי רחובות'}
# Player number:  382   {'name': 'זוריק מנשה', 'id': '1878', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  383   {'name': 'אומר חטמוב', 'id': '1268', 'club': 'הפועל ירושלים'}
# Player number:  384   {'name': 'שלמה ביגר', 'id': '4035', 'club': 'אופק קריית אונו'}
# Player number:  386   {'name': 'נתנאל מזרחי', 'id': '3033', 'club': 'הפועל ירושלים'}
# Player number:  387   {'name': "יורי קוצ'ר", 'id': '2049', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  388   {'name': 'שמואל גושן', 'id': '1682', 'club': 'מ. בני הרצליה'}
# Player number:  390   {'name': 'יעקב שקולניק', 'id': '1393', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  393   {'name': 'אשר בר', 'id': '1779', 'club': 'מכבי שהם'}
# Player number:  394   {'name': 'דניאל בורכוב', 'id': '7011', 'club': "טנ''ש 2007 נתניה"}
# Player number:  395   {'name': 'סרגיי סקובלו', 'id': '4248', 'club': 'מכבי גבירול באר שבע'}
# Player number:  396   {'name': 'יורי בונדרנקו', 'id': '6880', 'club': 'הפועל לוד'}
# Player number:  397   {'name': 'יוגב שול', 'id': '924', 'club': 'הפועל באר טוביה'}
# Player number:  398   {'name': 'אורי אוליצקי', 'id': '3999', 'club': "טנ''ש 2007 נתניה"}
# Player number:  399   {'name': 'פרדי אמינוב', 'id': '1010', 'club': 'הפועל בת ים'}
# Player number:  401   {'name': 'רן פרץ', 'id': '1434', 'club': 'הפועל רמת ישי'}
# Player number:  402   {'name': 'מיכאל מוגורדומוב', 'id': '4169', 'club': "בית''ר אשדוד"}
# Player number:  404   {'name': 'שמואל שמואלי', 'id': '3378', 'club': 'הפועל ירושלים'}
# Player number:  405   {'name': 'דוד סיבוני', 'id': '2862', 'club': "מ.ק.מתנ''ס קריית גת"}
# Player number:  406   {'name': 'יפים פוגורלוב', 'id': '1011', 'club': 'הפועל בת ים'}
# Player number:  407   {'name': 'גיל איתן', 'id': '4792', 'club': 'מכבי תל אביב'}
# Player number:  408   {'name': 'גור רולניק', 'id': '1950', 'club': "בית''ר רמלה"}
# Player number:  409   {'name': 'ראובן רוזן', 'id': '1390', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  410   {'name': 'אבי וידן', 'id': '2096', 'club': 'הפועל דרום השרון'}
# Player number:  413   {'name': 'פליקס ברלין', 'id': '1702', 'club': 'מכבי גבירול באר שבע'}
# Player number:  414   {'name': 'בן ציון הבדלה', 'id': '1457', 'club': 'מכבי רמת יצחק רמת גן'}
# Player number:  415   {'name': 'אלכסנדר שרמן', 'id': '302', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  416   {'name': 'חן עזריה', 'id': '773', 'club': 'מכבי שהם'}
# Player number:  417   {'name': 'יובל טולדנו', 'id': '6668', 'club': 'מכבי עירוני שדרות'}
# Player number:  418   {'name': 'ויאצסלב בלץ', 'id': '1636', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  419   {'name': 'ניסים באבי', 'id': '4718', 'club': "מ.ק.מתנ''ס קריית גת"}
# Player number:  420   {'name': 'משה קאיט', 'id': '2083', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  421   {'name': 'ארנסט קלדררו', 'id': '1209', 'club': 'מכבי עירוני שדרות'}
# Player number:  425   {'name': 'יניב עוזר', 'id': '1231', 'club': 'אליצור קריית אתא'}
# Player number:  426   {'name': 'יואב זהר', 'id': '1389', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  427   {'name': 'אלכסנדר קושבצקי', 'id': '1235', 'club': 'אליצור קריית אתא'}
# Player number:  428   {'name': 'בנימין רחמינוב', 'id': '1228', 'club': 'אליצור קריית אתא'}
# Player number:  430   {'name': 'ארז יצחק', 'id': '3680', 'club': 'הפועל לוד'}
# Player number:  432   {'name': 'ברק דוידוביץ', 'id': '4262', 'club': 'הפועל אשדוד'}
# Player number:  433   {'name': 'איגור קוגן', 'id': '533', 'club': 'הפועל חיפה'}
# Player number:  434   {'name': 'רומן אמינוב', 'id': '4011', 'club': "בית''ר אשדוד"}
# Player number:  435   {'name': 'יעקב היילברונר', 'id': '7067', 'club': 'אופק קריית אונו'}
# Player number:  436   {'name': 'בנימין פרידמן', 'id': '2278', 'club': 'הפועל מבואות חרמון'}
# Player number:  437   {'name': 'ניר פינקלשטיין', 'id': '4501', 'club': "בית''ר באר שבע"}
# Player number:  438   {'name': 'מרטין חרקובר', 'id': '2193', 'club': 'מכבי שהם'}
# Player number:  439   {'name': 'נועם נימרודי', 'id': '6979', 'club': 'הפועל פתח תקווה'}
# Player number:  442   {'name': 'דניאל וקנין', 'id': '1173', 'club': 'הפועל לוד'}
# Player number:  443   {'name': 'פליקס חכם', 'id': '2627', 'club': 'הפועל פתח תקווה'}
# Player number:  444   {'name': 'צחי גיגי', 'id': '951', 'club': 'מ. בני הרצליה'}
# Player number:  445   {'name': 'הראל יפת', 'id': '3832', 'club': 'אופק קריית אונו'}
# Player number:  446   {'name': 'רוסלן פינקלשטיין', 'id': '3972', 'club': 'הפועל ארנון רמת גן'}
# Player number:  447   {'name': 'אריאל שימונוב', 'id': '4517', 'club': 'מכבי דימונה'}
# Player number:  448   {'name': 'יעקב קרקר', 'id': '1559', 'club': 'הפועל חיפה'}
# Player number:  449   {'name': 'ניר אולשר', 'id': '6895', 'club': 'אופק קריית אונו'}
# Player number:  450   {'name': 'רומן סיגלוב', 'id': '933', 'club': "טנ''ש נס ציונה"}
# Player number:  452   {'name': "ויאצ'סלב סנדקוב", 'id': '4805', 'club': 'הפועל מבואות חרמון'}
# Player number:  453   {'name': 'סיאמק לקן', 'id': '5680', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  454   {'name': 'איליה ברונשטיין', 'id': '2955', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  456   {'name': 'ארטיום מרטיסיוק', 'id': '3008', 'club': 'הפועל בת ים'}
# Player number:  457   {'name': 'יהונתן דהן', 'id': '2065', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  458   {'name': 'דויד אסוביץ', 'id': '1155', 'club': 'הפועל ירושלים'}
# Player number:  460   {'name': 'סהר ברוך', 'id': '5731', 'club': 'הפועל לוד'}
# Player number:  461   {'name': 'פיליפ זייציק', 'id': '1663', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  462   {'name': 'אלכס וייסמן', 'id': '1293', 'club': "בית''ר רמלה"}
# Player number:  464   {'name': 'שחר טל', 'id': '1643', 'club': 'מכבי שהם'}
# Player number:  465   {'name': 'ולדיסלב לשציוב', 'id': '2954', 'club': 'הפועל אשקלון'}
# Player number:  466   {'name': 'ויאציסלב סוסונוב', 'id': '1340', 'club': 'מכבי גבירול באר שבע'}
# Player number:  467   {'name': 'איל רונן', 'id': '7541', 'club': 'מ. בני הרצליה'}
# Player number:  470   {'name': 'ולדיסלב קניגין', 'id': '2055', 'club': "הפועל טנ''ש באר שבע"}
# Player number:  472   {'name': 'אנדריי פלייר', 'id': '1766', 'club': 'הפועל ירושלים'}
# Player number:  473   {'name': 'יואב קמק', 'id': '4146', 'club': 'אופק קריית אונו'}
# Player number:  474   {'name': 'יורם פזנד', 'id': '1630', 'club': "טנ''ש 2007 נתניה"}
# Player number:  475   {'name': 'בוריס סמיונוב', 'id': '309', 'club': 'מועדון ספורט מעלה אדומים'}
# Player number:  476   {'name': 'חיימי שלום', 'id': '5753', 'club': 'עירוני גבעתיים'}
# Player number:  477   {'name': 'שארלי אבגי', 'id': '2188', 'club': 'הפועל עירוני נוף הגליל'}
# Player number:  480   {'name': 'משה מור', 'id': '3383', 'club': 'הפועל ירושלים'}
# Player number:  481   {'name': 'מאיר כהן', 'id': '5648', 'club': 'הפועל ירושלים'}
# Player number:  482   {'name': 'יהושע פפר', 'id': '5712', 'club': 'הפועל ירושלים'}
# Player number:  483   {'name': 'פואד ליאור שלמה', 'id': '3867', 'club': 'עמותת קריית מוצקין'}
# Player number:  484   {'name': 'אליהו כהן', 'id': '3391', 'club': 'הפועל ירושלים'}
# Player number:  485   {'name': 'גיל ספורטה', 'id': '2958', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  486   {'name': 'יניב כץ', 'id': '5674', 'club': 'עירוני גבעתיים'}
# Player number:  487   {'name': 'יבגני גולנדר', 'id': '3114', 'club': "בית''ר ראשון לציון"}
# Player number:  489   {'name': 'עדי לוי', 'id': '7458', 'club': 'הפועל מבואות חרמון'}
# Player number:  490   {'name': 'יצחק מיאלי', 'id': '1683', 'club': 'מ. בני הרצליה'}
# Player number:  491   {'name': 'אוריאל מרציאנו', 'id': '5506', 'club': 'מ. טנ"ש ויקטור נתניה'}
# Player number:  492   {'name': 'לאוניד וטמכר', 'id': '896', 'club': "טנ''ש נס ציונה"}
# Player number:  493   {'name': 'יעקובוב ארטור', 'id': '2945', 'club': 'הפועל חולון'}
# Player number:  496   {'name': 'נאור יעקובוב', 'id': '5657', 'club': "בית''ר ראשון לציון"}
# Player number:  497   {'name': 'מזהר מגאדלי', 'id': '1498', 'club': "הפועל מתנ''ס בקה אל גרבייה"}
# Player number:  498   {'name': 'גיל אלבר', 'id': '944', 'club': 'מכבי זאב זכרון יעקב'}
# Player number:  499   {'name': 'טארק קעדאן', 'id': '3015', 'club': "הפועל מתנ''ס בקה אל גרבייה"}

# %%
games_df = pd.DataFrame.from_dict(games_to_df)
games_df
# Out:
#       match_id               match_type       date p1_id        p1_name  \
# 0       338816  ליגת על גברים 2022-2023 2023-01-03   745  יונתן שוסטרמן
# 1       337989  ליגת על גברים 2022-2023 2022-12-27   745  יונתן שוסטרמן
# 2       337992  ליגת על גברים 2022-2023 2022-12-27   745  יונתן שוסטרמן
# 3       337511  ליגת על גברים 2022-2023 2022-12-25   745  יונתן שוסטרמן
# 4       337516  ליגת על גברים 2022-2023 2022-12-25   745  יונתן שוסטרמן
# ...        ...                      ...        ...   ...            ...
# 65099   293649   ליגת א גברים 2021-2022 2022-03-02  3015     טארק קעדאן
# 65100   293651   ליגת א גברים 2021-2022 2022-03-02  3015     טארק קעדאן
# 65101   293653   ליגת א גברים 2021-2022 2022-03-02  3015     טארק קעדאן
# 65102   290032   ליגת א גברים 2021-2022 2022-02-16  3015     טארק קעדאן
# 65103   290034   ליגת א גברים 2021-2022 2022-02-16  3015     טארק קעדאן
#
#                           p1_club  p1_rank  p1_sets  p1_home  \
# 0                   מ. בני הרצליה   1807.8        2      1.0
# 1                   מ. בני הרצליה   1800.3        3      0.0
# 2                   מ. בני הרצליה   1800.3        3      0.0
# 3                   מ. בני הרצליה   1800.3        3      1.0
# 4                   מ. בני הרצליה   1800.3        3      1.0
# ...                           ...      ...      ...      ...
# 65099  הפועל מתנ''ס בקה אל גרבייה    469.0        0      0.0
# 65100  הפועל מתנ''ס בקה אל גרבייה    469.0        3      0.0
# 65101  הפועל מתנ''ס בקה אל גרבייה    469.0        0      0.0
# 65102  הפועל מתנ''ס בקה אל גרבייה    459.0        3      1.0
# 65103  הפועל מתנ''ס בקה אל גרבייה    459.0        3      1.0
#
#        p1_points_gained  p2_id        p2_name                     p2_club  \
# 0                 -10.5    676      עמית גורן      הפועל עירוני נוף הגליל
# 1                   1.5    926      שימי אסרף                  הפועל חיפה
# 2                   1.5   1844        נדב דהן                  הפועל חיפה
# 3                   1.5   6601   מקסים גולדין  כרמל מרכזי טניס שולחן חיפה
# 4                   3.0    685    יניב קרמזין  כרמל מרכזי טניס שולחן חיפה
# ...                 ...    ...            ...                         ...
# 65099              -1.0   1579       אסף גונן         מכבי זאב זכרון יעקב
# 65100               5.0   3947       ליאב כהן         מכבי זאב זכרון יעקב
# 65101              -2.0    526   גילעד הוזליך         מכבי זאב זכרון יעקב
# 65102               6.0   1514  אלכסנדר וולוך         מכבי זאב זכרון יעקב
# 65103               4.0   6478       אדם שורץ         מכבי זאב זכרון יעקב
#
#        p2_rank  p2_sets  p2_home  p2_points_gained winner_id
# 0       1712.4        3      0.0             15.75       676
# 1       1071.1        0      1.0             -1.00       745
# 2       1133.6        0      1.0             -1.00       745
# 3       1057.6        0      0.0             -1.00       745
# 4       1368.9        0      0.0             -2.00       745
# ...        ...      ...      ...               ...       ...
# 65099    871.6        3      1.0              1.00      1579
# 65100    302.1        1      1.0             -5.00      3015
# 65101    721.2        3      1.0              2.00       526
# 65102    351.3        0      0.0             -6.00      3015
# 65103    241.6        0      0.0             -4.00      3015
#
# [65104 rows x 18 columns]

# %%
# games_df = games_df.drop_duplicates('match_id')
# We remove the duplicated games later in the processing

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65104 entries, 0 to 65103
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          65104 non-null  object
#  1   match_type        65104 non-null  object
#  2   date              65104 non-null  datetime64[ns]
#  3   p1_id             65104 non-null  object
#  4   p1_name           65104 non-null  object
#  5   p1_club           65104 non-null  object
#  6   p1_rank           65104 non-null  float64
#  7   p1_sets           65104 non-null  int64
#  8   p1_home           41681 non-null  float64
#  9   p1_points_gained  65104 non-null  float64
#  10  p2_id             65104 non-null  int64
#  11  p2_name           65104 non-null  object
#  12  p2_club           65104 non-null  object
#  13  p2_rank           65104 non-null  float64
#  14  p2_sets           65104 non-null  int64
#  15  p2_home           41681 non-null  float64
#  16  p2_points_gained  65104 non-null  float64
#  17  winner_id         65104 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(3), object(8)
# memory usage: 8.9+ MB

# %%
games_df.to_csv("games_data_table.csv", sep=",", encoding="utf-8-sig")
